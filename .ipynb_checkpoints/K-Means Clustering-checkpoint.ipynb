# %%
import librosa
import IPython.display as ipd
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import os
import csv
from sklearn.preprocessing import Normalizer, MinMaxScaler, StandardScaler
from sklearn.cluster import MeanShift, KMeans
from sklearn.pipeline import Pipeline
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split, cross_validate
from sklearn.metrics import adjusted_rand_score, adjusted_mutual_info_score, silhouette_score, v_measure_score
from sklearn.metrics import confusion_matrix 
from sklearn.metrics import accuracy_score 
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report

# %%
# Dropping unneccesary columns
dataset = pd.read_csv('extractedmusicfeaturesetallfeatures.csv')
dataset = dataset.drop(['Filename'],axis=1) #Filename is not required
dataset.head()
# Out:
#    Chromagram  RootMeanSquare  LowEnergyBrightness  SpectralCentroid  \
# 0    0.308197        0.082482            23.698370       1535.037572
# 1    0.301338        0.064592            24.126800       1178.338976
# 2    0.296208        0.121434            25.195057       1303.581375
# 3    0.378564        0.117686            23.537749        765.650527
# 4    0.261476        0.060902            25.022190       1539.421609
#
#    Flatness    Bandwidth  InHarmonicity      Rolloff  ZeroCrossingRate  \
# 0  0.001726  1834.035228       0.000684  3175.514131          0.070391
# 1  0.000634  1719.624593       0.018852  2425.427000          0.044456
# 2  0.000763  1579.884288       0.022247  2479.285008          0.064793
# 3  0.000240  1289.465222       0.008652  1387.583276          0.024866
# 4  0.001334  1584.038983      -0.050764  2954.190470          0.085597
#
#         mfcc1  ...    mfcc12    mfcc13     mfcc14     mfcc15    mfcc16  \
# ...

# %%
features = ['Chromagram','RootMeanSquare','LowEnergyBrightness','SpectralCentroid','Flatness','Bandwidth','InHarmonicity','Rolloff','ZeroCrossingRate','mfcc1','mfcc2','mfcc3','mfcc4','mfcc5','mfcc6','mfcc7','mfcc8','mfcc9','mfcc10','mfcc11','mfcc12','mfcc13','mfcc14','mfcc15','mfcc16','mfcc17','mfcc18','mfcc19','mfcc20']

# %%
X_prenorm = dataset[features]
pd.DataFrame(X_prenorm,columns=features).hist(figsize=(20,30), normed=True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\hist.py:412: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   ax.hist(data[col].dropna().values, bins=bins, **kwds)
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000250D0DD78C8>,
# ...
#       dtype=object)

# %%
genre_count = dataset.groupby('label').agg({'label':'count'})['label']
print(genre_count)
# Out:
# label
# blues        100
# classical    100
# country      100
# disco        100
# hiphop       100
# jazz         100
# metal        100
# pop          100
# reggae       100
# rock         100
# Name: label, dtype: int64

# %%
norm = Normalizer()
dataset[features] = norm.fit_transform(dataset[features])

# %%
genre_groupby = dataset.groupby('label').agg('mean')
clusters = genre_groupby.reset_index().rename({'label':'cluster'}, axis=1)
clusters['method'] = 'Mean'

oldclusters = clusters
oldclusters
# Out:
#      cluster  Chromagram  RootMeanSquare  LowEnergyBrightness  \
# 0      blues    0.000094        0.000031             0.008116
# 1  classical    0.000090        0.000013             0.009759
# 2    country    0.000088        0.000028             0.007553
# 3      disco    0.000063        0.000016             0.004298
# 4     hiphop    0.000075        0.000022             0.004079
# 5       jazz    0.000080        0.000022             0.007650
# 6      metal    0.000074        0.000019             0.004176
# 7        pop    0.000052        0.000021             0.003432
# 8     reggae    0.000091        0.000022             0.005943
# 9       rock    0.000075        0.000021             0.005494
#
#    SpectralCentroid      Flatness  Bandwidth  InHarmonicity   Rolloff  \
# 0          0.380853  2.561423e-07   0.498814   1.182952e-06  0.760179
# 1          0.422302  1.974365e-07   0.477971   1.701148e-06  0.746459
# 2          0.382816  6.450093e-07   0.488907   6.384716e-07  0.774607
# ...

# %%
dataset[features].hist(figsize=(20,30), normed=True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\hist.py:412: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   ax.hist(data[col].dropna().values, bins=bins, **kwds)
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000250D72F5C48>,
# ...
#       dtype=object)

# %%
X = dataset[['Chromagram','RootMeanSquare','LowEnergyBrightness','SpectralCentroid','Flatness',
          'Bandwidth','InHarmonicity','Rolloff','ZeroCrossingRate','mfcc1','mfcc2','mfcc3',
          'mfcc4','mfcc5','mfcc6','mfcc7','mfcc8','mfcc9','mfcc10','mfcc11','mfcc12','mfcc13',
          'mfcc14','mfcc15','mfcc16','mfcc17','mfcc18','mfcc19','mfcc20']]

Ks = np.arange(1, 20)
km = [KMeans(n_clusters=i, random_state=1986) for i in Ks]
score = [-km[i].fit(X).score(X) for i in range(len(km))]
Ks.dtype = int
plt.figure(figsize=(8,8))
plt.plot(Ks,score)
plt.xlim(0,18)
plt.grid(True)
plt.xlabel('K')
plt.ylabel('Error')
plt.title('Elbow Method')
# Out:
# Text(0.5, 1.0, 'Elbow Method')

# %%
Ks = np.arange(2, 30)
kms = [KMeans(n_clusters=i, random_state=1986).fit(X) for i in Ks]
s_scores = [silhouette_score(X,kms[i].labels_) for i in range(2,len(Ks))]
plt.figure(figsize=(8,8))
plt.plot(Ks[2:len(Ks)],s_scores)
#plt.xlim(0,18)
plt.grid(True)
plt.xlabel('K')
# Out:
# Text(0.5, 0, 'K')

# %%
X = dataset[['Chromagram','RootMeanSquare','LowEnergyBrightness','SpectralCentroid','Flatness',
             'Bandwidth','InHarmonicity','Rolloff','ZeroCrossingRate','mfcc1','mfcc2','mfcc3',
             'mfcc4','mfcc5','mfcc6','mfcc7','mfcc8','mfcc9','mfcc10','mfcc11','mfcc12','mfcc13',
             'mfcc14','mfcc15','mfcc16','mfcc17','mfcc18','mfcc19','mfcc20']]
km = KMeans(n_clusters=len(genre_groupby), n_init=10, random_state=1986)
km.fit(X)
labels = km.labels_
cluster_centers = km.cluster_centers_
labels_unique = np.unique(labels)
n_clusters_ = len(labels_unique)
km_clusters = pd.DataFrame(cluster_centers, columns=features)
km_clusters['cluster'] = ['KM{}'.format(l) for l in labels_unique]
km_clusters['method'] = 'KMeans'
oldclusters = pd.concat([oldclusters, km_clusters])
cols = ['cluster'] + features + ['method']
oldclusters = oldclusters[cols]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:14: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.

# %%
newclusters = oldclusters

# %%
newclusters
# Out:
#      cluster  Chromagram  RootMeanSquare  LowEnergyBrightness  \
# 0      blues    0.000094        0.000031             0.008116
# 1  classical    0.000090        0.000013             0.009759
# 2    country    0.000088        0.000028             0.007553
# 3      disco    0.000063        0.000016             0.004298
# 4     hiphop    0.000075        0.000022             0.004079
# 5       jazz    0.000080        0.000022             0.007650
# 6      metal    0.000074        0.000019             0.004176
# 7        pop    0.000052        0.000021             0.003432
# 8     reggae    0.000091        0.000022             0.005943
# 9       rock    0.000075        0.000021             0.005494
# 0        KM0    0.000127        0.000042             0.011466
# 1        KM1    0.000056        0.000019             0.003535
# 2        KM2    0.000088        0.000026             0.006838
# 3        KM3    0.000118        0.000020             0.012559
# ...

# %%
### Assign K-Means Label to Descriptive Labels
descriptive_labels = ["Slow & Somber Acoustics", "Sad Instrumentals", "Upbeat Songs With Cheerful Vocals", 
 "Fast & Danceable Instrumentals", "Fast, Upbeat & Cheerful Songs", "Happy & Upbeat Instrumentals",
 "Aggressive, Fast Paced Acoustics", "Slow Happy Dance", "Happy & Slow", 
 "Fast, Upbeat & Cheerful Acoustics"]

unique_labels = np.unique(labels)
label_translation = dict(zip(unique_labels, descriptive_labels))
dataset['KMeansLabel'] = list(map(lambda x:label_translation[x], labels))

genre_count = dataset.groupby('label').agg({'label':'count'})['label']

# Calculates how many KMeans clusters there are?
print("### Instances of KMeans Cluster ###")
print(dataset[['label', 'KMeansLabel']].groupby('KMeansLabel').agg('count'))

# Which cluster corresponds to the most instances per genre?
print("### Which cluster corresponds to the most instances per genre? ###")
print(dataset[['label', 'KMeansLabel']].groupby('label').agg(lambda x:x.value_counts().index[0]))

# Which genre corresponds to the most instances per cluster?
print("### Which genre corresponds to the most instances per cluster? ###")
print(dataset[['label', 'KMeansLabel']].groupby('KMeansLabel').agg(lambda x:x.value_counts().index[0]))
# Out:
# ### Instances of KMeans Cluster ###
#                                    label
# KMeansLabel
# Aggressive, Fast Paced Acoustics     103
# Fast & Danceable Instrumentals        35
# Fast, Upbeat & Cheerful Acoustics     78
# Fast, Upbeat & Cheerful Songs        159
# Happy & Slow                         151
# Happy & Upbeat Instrumentals          12
# Sad Instrumentals                    221
# Slow & Somber Acoustics               34
# Slow Happy Dance                      84
# Upbeat Songs With Cheerful Vocals    123
# ### Which cluster corresponds to the most instances per genre? ###
#                                  KMeansLabel
# label
# blues      Fast, Upbeat & Cheerful Acoustics
# classical                   Slow Happy Dance
# country    Upbeat Songs With Cheerful Vocals
# disco                      Sad Instrumentals
# hiphop                     Sad Instrumentals
# jazz       Upbeat Songs With Cheerful Vocals
# metal                           Happy & Slow
# ...

# %%
y_true_label = dataset['label']
y_pred_label = dataset['KMeansLabel']
kmeans_metrics = {'adjusted_rand_score':adjusted_rand_score, 
           'adjusted_mutual_info_score':adjusted_mutual_info_score, 
           'v_measure_score':v_measure_score
          }
silhouette_scores = dict(zip(kmeans_metrics.keys(), [kmeans_metrics[m](y_true_label, y_pred_label) for m in kmeans_metrics.keys()]))
silhouette_scores['silhouette_score'] = silhouette_score(X,y_pred_label)
for i,y in silhouette_scores.items():
    print("KMeans Metric: {} Score: {}".format(i, y))
# Out:
# KMeans Metric: adjusted_rand_score Score: 0.11547242184249254
# KMeans Metric: adjusted_mutual_info_score Score: 0.18941810520725275
# KMeans Metric: v_measure_score Score: 0.21404572899895544
# KMeans Metric: silhouette_score Score: 0.2968615978807961
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\cluster\supervised.py:746: FutureWarning: The behavior of AMI will change in version 0.22. To match the behavior of 'v_measure_score', AMI will use average_method='arithmetic' by default.
#   FutureWarning)

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=2)
X_new = pca.fit_transform(X)
x,y = zip(*X_new)
dataset['x'] = x
dataset['y'] = y
components = pca.components_
variance = pca.explained_variance_
variance = pca.explained_variance_ratio_
values = pca.singular_values_

# %%
audio = dict(list(zip(features, zip(*np.round(components,2)))))
audio
# Out:
# {'Chromagram': (0.0, 0.0),
#  'RootMeanSquare': (0.0, -0.0),
#  'LowEnergyBrightness': (0.03, 0.03),
#  'SpectralCentroid': (0.01, 0.62),
#  'Flatness': (-0.0, -0.0),
#  'Bandwidth': (0.69, -0.5),
#  'InHarmonicity': (0.0, 0.0),
#  'Rolloff': (-0.54, -0.11),
#  'ZeroCrossingRate': (-0.0, 0.0),
#  'mfcc1': (-0.45, -0.56),
#  'mfcc2': (0.17, 0.18),
#  'mfcc3': (0.03, -0.07),
#  'mfcc4': (0.02, 0.0),
#  'mfcc5': (0.02, -0.02),
#  'mfcc6': (0.0, -0.02),
#  'mfcc7': (0.0, -0.02),
#  'mfcc8': (-0.0, -0.02),
#  'mfcc9': (-0.0, -0.02),
#  'mfcc10': (-0.01, -0.01),
#  'mfcc11': (-0.0, -0.02),
#  'mfcc12': (-0.01, -0.01),
#  'mfcc13': (-0.0, -0.01),
#  'mfcc14': (-0.01, -0.01),
#  'mfcc15': (-0.0, -0.0),
#  'mfcc16': (-0.01, -0.0),
#  'mfcc17': (-0.0, 0.0),
#  'mfcc18': (-0.0, 0.0),
#  'mfcc19': (-0.0, -0.0),
#  'mfcc20': (-0.01, 0.0)}

# %%
values
# Out:
# array([3.17673917, 1.20743642])

# %%
sns.set(font_scale=1.5)
sns.lmplot(data=dataset, x='x', y='y', hue='label', fit_reg=False, legend=True, size=8, palette='Set1',
           scatter_kws={'alpha':0.35, 's':25})
plt.savefig('pca_scatterplot_genres.png')
plt.title("Clustering by Genre, Normal Dimensionality")
# Out:
# Text(0.5, 1, 'Clustering by Genre, Normal Dimensionality')

# %%
sns.set(font_scale=1.5)
sns.lmplot(data=dataset, x='x', y='y', hue='KMeansLabel', fit_reg=False, legend=True, size=8, palette='Set1',
           scatter_kws={'alpha':0.35, 's':25})
plt.title("Clustering by KMeans Label, Reduced Dimensionality")
plt.savefig('pca_scatterplot_KMeans.png')

# %%
dataset
# Out:
#      Chromagram  RootMeanSquare  LowEnergyBrightness  SpectralCentroid  \
# 0      0.000077        0.000021             0.005951          0.385474
# 1      0.000094        0.000020             0.007507          0.366620
# 2      0.000092        0.000038             0.007815          0.404323
# 3      0.000183        0.000057             0.011384          0.370291
# 4      0.000071        0.000016             0.006764          0.416164
# ..          ...             ...                  ...               ...
# 995    0.000074        0.000016             0.006396          0.378084
# 996    0.000082        0.000014             0.006330          0.397971
# 997    0.000084        0.000014             0.005971          0.412492
# 998    0.000114        0.000025             0.009051          0.364899
# 999    0.000099        0.000015             0.008299          0.393012
#
#          Flatness  Bandwidth  InHarmonicity   Rolloff  ZeroCrossingRate  \
# ...
